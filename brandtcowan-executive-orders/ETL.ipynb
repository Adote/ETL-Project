# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
presi_csv = "Resources/documents_of_type_presidential_document_and_of_presidential_document_type_executive_order.csv"
execu_csv = "Resources/executive_orders.csv"
subtop_csv = "Resources/SubTopics.csv"
topco_csv = "Resources/TopicCode.csv"

# %%
presi_df = pd.read_csv(presi_csv)
presi_df = presi_df.astype({"executive_order_number": float})
presi_df.head()
# Out:
#   citation document_number  end_page  \
# 0      NaN          94-290         0
# 1      NaN         94-1531         0
# 2      NaN         94-1532         0
# 3      NaN         94-2261         0
# 4      NaN         94-2267         0
#
#                                executive_order_notes  executive_order_number  \
# 0                                                NaN                 12890.0
# 1           Revoked by: EO 13062, September 29, 1997                 12891.0
# 2  Amends: EO 11063, November 20, 1962;;\n ;  Rev...                 12892.0
# 3  Revokes: EO 11063, November 20, 1962 (in part)...                 12893.0
# 4                  See: Memorandum, January 17, 1994                 12894.0
#
#                                             html_url pdf_url publication_date  \
# 0  https://www.federalregister.gov/documents/1994...     NaN       01/05/1994
# 1  https://www.federalregister.gov/documents/1994...     NaN       01/20/1994
# 2  https://www.federalregister.gov/documents/1994...     NaN       01/20/1994
# 3  https://www.federalregister.gov/documents/1994...     NaN       01/31/1994
# 4  https://www.federalregister.gov/documents/1994...     NaN       01/31/1994
#
#   signing_date  start_page                                              title
# 0   12/30/1993           0             Amendment to Executive Order No. 12864
# 1   01/15/1994           0  Advisory Committee on Human Radiation Experiments
# 2   01/17/1994           0  Leadership and Coordination of Fair Housing in...
# 3   01/26/1994           0  Principles for Federal Infrastructure Investments
# 4   01/26/1994           0          North Pacific Marine Science Organization

# %%
# presi_df.info()
# Create a filtered dataframe from specific columns
presi_cols = ["executive_order_number"]
presid_df = presi_df[presi_cols].copy()

# Rename the column headers
presid_df = presid_df.rename(columns={"executive_order_number": "Exec_Ord"})
presid_df.head()
# Out:
#    Exec_Ord
# 0   12890.0
# 1   12891.0
# 2   12892.0
# 3   12893.0
# 4   12894.0

# %%
execu_df = pd.read_csv(execu_csv)
execu_df['pres_party'] = execu_df['pres_party'].map({100: 'Democrat', 200: 'Republican'})
execu_cols = ["eo_number", "president", "pres_party", "year", "majortopic", "subtopic"]
execut_df = execu_df[execu_cols].copy()
execut_df = execut_df.rename(columns={"eo_number": "Exec_Ord", "president":"President", "pres_party": "Party", "year":"Year", "majortopic":"Topic", "subtopic": "Sub_Topic"})
execut_df.head()
# Out:
#    Exec_Ord President     Party  Year  Topic  Sub_Topic
# 0    9538.0    TRUMAN  Democrat  1945     20       2004
# 1    9539.0    TRUMAN  Democrat  1945     19       1929
# 2    9540.0    TRUMAN  Democrat  1945     16       1610
# 3    9541.0    TRUMAN  Democrat  1945     20       2007
# 4    9542.0    TRUMAN  Democrat  1945     16       1610

# %%
# execu_df.info()
# Merge two dataframes using an outer join
merge_table1 = pd.merge(presid_df, execut_df, on="Exec_Ord", how="outer")
merge_table1.drop_duplicates(subset=['Exec_Ord'], keep=False)
merge_table1.head()
# Out:
#    Exec_Ord President     Party    Year  Topic  Sub_Topic
# 0   12890.0   CLINTON  Democrat  1993.0   17.0     1709.0
# 1   12891.0   CLINTON  Democrat  1994.0    3.0      398.0
# 2   12892.0   CLINTON  Democrat  1994.0   14.0     1400.0
# 3   12893.0   CLINTON  Democrat  1994.0   10.0     1010.0
# 4   12894.0   CLINTON  Democrat  1994.0   19.0     1926.0

# %%
merge_table11 = merge_table1.dropna(how='all')
merge_table11.head()
# Out:
#    Exec_Ord President     Party    Year  Topic  Sub_Topic
# 0   12890.0   CLINTON  Democrat  1993.0   17.0     1709.0
# 1   12891.0   CLINTON  Democrat  1994.0    3.0      398.0
# 2   12892.0   CLINTON  Democrat  1994.0   14.0     1400.0
# 3   12893.0   CLINTON  Democrat  1994.0   10.0     1010.0
# 4   12894.0   CLINTON  Democrat  1994.0   19.0     1926.0

# %%
merge_table11 = merge_table11.astype({"Sub_Topic": float})

# %%
subtop_df = pd.read_csv(subtop_csv, encoding='windows-1252')
subtop_df = subtop_df.rename(columns={"Code": "Sub_Topic", "SubTopic": "Sub_Topic_Title"})
subtop_df.head()
# Out:
#    Sub_Topic     Sub_Topic_Title  \
# 0        100             General
# 1        101      Interest Rates
# 2        103   Unemployment Rate
# 3        104     Monetary Policy
# 4        105     National Budget
#
#                                          Description
# 0   Includes issues related to general domestic m...
# 1   Includes issues related to inflation, cost of...
# 2   Includes issues related to the unemployment r...
# 3   Includes issues related to the monetary polic...
# 4   Issues related to public debt, budgeting, and...

# %%
# Merge two dataframes using an outer join
merge_table2 = pd.merge(subtop_df, merge_table11, on="Sub_Topic", how="outer")
merge_table2.drop_duplicates(subset=['Sub_Topic'], keep=False)
merge_table2.head()
# Out:
#    Sub_Topic Sub_Topic_Title  \
# 0      100.0         General
# 1      100.0         General
# 2      100.0         General
# 3      100.0         General
# 4      100.0         General
#
#                                          Description  Exec_Ord President  \
# 0   Includes issues related to general domestic m...   12912.0   CLINTON
# 1   Includes issues related to general domestic m...   13497.0     OBAMA
# 2   Includes issues related to general domestic m...   13499.0     OBAMA
# 3   Includes issues related to general domestic m...   13500.0     OBAMA
# 4   Includes issues related to general domestic m...   13501.0     OBAMA
#
#       Party    Year  Topic
# 0  Democrat  1994.0    1.0
# 1  Democrat  2009.0    1.0
# 2  Democrat  2009.0    1.0
# 3  Democrat  2009.0    1.0
# 4  Democrat  2009.0    1.0

# %%
topco_df = pd.read_csv(topco_csv)
topco_df = topco_df.rename(columns={"Code": "Topic", "Topic": "Topic_Title"})
topco_df = topco_df.astype({"Topic": float})
topco_df.head()
# Out:
#    Topic      Topic_Title
# 0    1.0   Macroeconomics
# 1    2.0     Civil Rights
# 2    3.0           Health
# 3    4.0      Agriculture
# 4    5.0            Labor

# %%
# Merge the two DataFrames together based on the Dates they share
merge_table3 = pd.merge(merge_table2, topco_df, on="Topic")
merge_table3.head()
# Out:
#    Sub_Topic Sub_Topic_Title  \
# 0      100.0         General
# 1      100.0         General
# 2      100.0         General
# 3      100.0         General
# 4      100.0         General
#
#                                          Description  Exec_Ord President  \
# 0   Includes issues related to general domestic m...   12912.0   CLINTON
# 1   Includes issues related to general domestic m...   13497.0     OBAMA
# 2   Includes issues related to general domestic m...   13499.0     OBAMA
# 3   Includes issues related to general domestic m...   13500.0     OBAMA
# 4   Includes issues related to general domestic m...   13501.0     OBAMA
#
#       Party    Year  Topic      Topic_Title
# 0  Democrat  1994.0    1.0   Macroeconomics
# 1  Democrat  2009.0    1.0   Macroeconomics
# 2  Democrat  2009.0    1.0   Macroeconomics
# 3  Democrat  2009.0    1.0   Macroeconomics
# 4  Democrat  2009.0    1.0   Macroeconomics

# %%
final_df = merge_table3.reindex_axis(['Exec_Ord',"Year","President","Party","Topic", "Sub_Topic","Topic_Title", "Sub_Topic_Title", "Description"], axis=1)
final_df
#.head()
# Out:
# /Users/adoteakpabie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.
#   """Entry point for launching an IPython kernel.
#       Exec_Ord    Year   President       Party  Topic  Sub_Topic  \
# 0      12912.0  1994.0     CLINTON    Democrat    1.0      100.0
# 1      13497.0  2009.0       OBAMA    Democrat    1.0      100.0
# 2      13499.0  2009.0       OBAMA    Democrat    1.0      100.0
# 3      13500.0  2009.0       OBAMA    Democrat    1.0      100.0
# 4      13501.0  2009.0       OBAMA    Democrat    1.0      100.0
# 5      13602.0  2012.0       OBAMA    Democrat    1.0      100.0
# 6      11453.0  1969.0       NIXON  Republican    1.0      100.0
# 7      11808.0  1974.0        FORD  Republican    1.0      100.0
# 8      11865.0  1975.0        FORD  Republican    1.0      100.0
# 9      11903.0  1976.0        FORD  Republican    1.0      100.0
# 10     11975.0  1977.0      CARTER    Democrat    1.0      100.0
# 11     12168.0  1979.0      CARTER    Democrat    1.0      100.0
# 12     12296.0  1981.0      REAGAN  Republican    1.0      100.0
# 13     12309.0  1981.0      REAGAN  Republican    1.0      100.0
# 14     12835.0  1993.0     CLINTON    Democrat    1.0      100.0
# 15     12878.0  1993.0     CLINTON    Democrat    1.0      100.0
# 16     12887.0  1993.0     CLINTON    Democrat    1.0      100.0
# 17     11821.0  1974.0        FORD  Republican    1.0      101.0
# 18     12161.0  1979.0      CARTER    Democrat    1.0      101.0
# 19      9953.0  1948.0      TRUMAN    Democrat    1.0      104.0
# 20     10289.0  1951.0      TRUMAN    Democrat    1.0      104.0
# 21     10583.0  1954.0  EISENHOWER  Republican    1.0      104.0
# 22     10586.0  1955.0  EISENHOWER  Republican    1.0      104.0
# 23     10626.0  1955.0  EISENHOWER  Republican    1.0      104.0
# 24     10882.0  1960.0  EISENHOWER  Republican    1.0      104.0
# 25     10896.0  1960.0  EISENHOWER  Republican    1.0      104.0
# 26     10905.0  1961.0  EISENHOWER  Republican    1.0      104.0
# 27     10941.0  1961.0     KENNEDY    Democrat    1.0      104.0
# 28     11037.0  1962.0     KENNEDY    Democrat    1.0      104.0
# 29     11110.0  1963.0     KENNEDY    Democrat    1.0      104.0
# ...        ...     ...         ...         ...    ...        ...
# 4160   10408.0  1952.0      TRUMAN    Democrat   21.0     2105.0
# 4161   10419.0  1952.0      TRUMAN    Democrat   21.0     2105.0
# 4162   10437.0  1953.0  EISENHOWER  Republican   21.0     2105.0
# 4163   10470.0  1953.0  EISENHOWER  Republican   21.0     2105.0
# 4164   10517.0  1954.0  EISENHOWER  Republican   21.0     2105.0
# 4165   10597.0  1955.0  EISENHOWER  Republican   21.0     2105.0
# 4166   10599.0  1955.0  EISENHOWER  Republican   21.0     2105.0
# 4167   10602.0  1955.0  EISENHOWER  Republican   21.0     2105.0
# 4168   10653.0  1956.0  EISENHOWER  Republican   21.0     2105.0
# 4169   10666.0  1956.0  EISENHOWER  Republican   21.0     2105.0
# 4170   10713.0  1957.0  EISENHOWER  Republican   21.0     2105.0
# 4171   10857.0  1959.0  EISENHOWER  Republican   21.0     2105.0
# 4172   10967.0  1961.0     KENNEDY    Democrat   21.0     2105.0
# 4173   10992.0  1962.0     KENNEDY    Democrat   21.0     2105.0
# 4174   11010.0  1962.0     KENNEDY    Democrat   21.0     2105.0
# 4175   11021.0  1962.0     KENNEDY    Democrat   21.0     2105.0
# 4176   11045.0  1962.0     KENNEDY    Democrat   21.0     2105.0
# 4177   11048.0  1962.0     KENNEDY    Democrat   21.0     2105.0
# 4178   11144.0  1964.0     JOHNSON    Democrat   21.0     2105.0
# 4179   11167.0  1964.0     JOHNSON    Democrat   21.0     2105.0
# 4180   11263.0  1965.0     JOHNSON    Democrat   21.0     2105.0
# 4181   11326.0  1967.0     JOHNSON    Democrat   21.0     2105.0
# 4182   11395.0  1968.0     JOHNSON    Democrat   21.0     2105.0
# 4183   11618.0  1971.0       NIXON  Republican   21.0     2105.0
# 4184   11944.0  1976.0        FORD  Republican   21.0     2105.0
# 4185   12084.0  1978.0      CARTER    Democrat   21.0     2105.0
# 4186   12569.0  1986.0      REAGAN  Republican   21.0     2105.0
# 4187   12572.0  1986.0      REAGAN  Republican   21.0     2105.0
# 4188   12690.0  1989.0        BUSH  Republican   21.0     2105.0
# 4189   12877.0  1993.0     CLINTON    Democrat   21.0     2105.0
#
#           Topic_Title              Sub_Topic_Title  \
# 0      Macroeconomics                      General
# 1      Macroeconomics                      General
# 2      Macroeconomics                      General
# 3      Macroeconomics                      General
# 4      Macroeconomics                      General
# 5      Macroeconomics                      General
# 6      Macroeconomics                      General
# 7      Macroeconomics                      General
# 8      Macroeconomics                      General
# 9      Macroeconomics                      General
# 10     Macroeconomics                      General
# 11     Macroeconomics                      General
# 12     Macroeconomics                      General
# 13     Macroeconomics                      General
# 14     Macroeconomics                      General
# 15     Macroeconomics                      General
# 16     Macroeconomics                      General
# 17     Macroeconomics               Interest Rates
# 18     Macroeconomics               Interest Rates
# 19     Macroeconomics              Monetary Policy
# 20     Macroeconomics              Monetary Policy
# 21     Macroeconomics              Monetary Policy
# 22     Macroeconomics              Monetary Policy
# 23     Macroeconomics              Monetary Policy
# 24     Macroeconomics              Monetary Policy
# 25     Macroeconomics              Monetary Policy
# 26     Macroeconomics              Monetary Policy
# 27     Macroeconomics              Monetary Policy
# 28     Macroeconomics              Monetary Policy
# 29     Macroeconomics              Monetary Policy
# ...               ...                          ...
# 4160     Public Lands   Dependencies & Territories
# 4161     Public Lands   Dependencies & Territories
# 4162     Public Lands   Dependencies & Territories
# 4163     Public Lands   Dependencies & Territories
# 4164     Public Lands   Dependencies & Territories
# 4165     Public Lands   Dependencies & Territories
# 4166     Public Lands   Dependencies & Territories
# 4167     Public Lands   Dependencies & Territories
# 4168     Public Lands   Dependencies & Territories
# 4169     Public Lands   Dependencies & Territories
# 4170     Public Lands   Dependencies & Territories
# 4171     Public Lands   Dependencies & Territories
# 4172     Public Lands   Dependencies & Territories
# 4173     Public Lands   Dependencies & Territories
# 4174     Public Lands   Dependencies & Territories
# 4175     Public Lands   Dependencies & Territories
# 4176     Public Lands   Dependencies & Territories
# 4177     Public Lands   Dependencies & Territories
# 4178     Public Lands   Dependencies & Territories
# 4179     Public Lands   Dependencies & Territories
# 4180     Public Lands   Dependencies & Territories
# 4181     Public Lands   Dependencies & Territories
# 4182     Public Lands   Dependencies & Territories
# 4183     Public Lands   Dependencies & Territories
# 4184     Public Lands   Dependencies & Territories
# 4185     Public Lands   Dependencies & Territories
# 4186     Public Lands   Dependencies & Territories
# 4187     Public Lands   Dependencies & Territories
# 4188     Public Lands   Dependencies & Territories
# 4189     Public Lands   Dependencies & Territories
#
#                                             Description
# 0      Includes issues related to general domestic m...
# 1      Includes issues related to general domestic m...
# 2      Includes issues related to general domestic m...
# 3      Includes issues related to general domestic m...
# 4      Includes issues related to general domestic m...
# 5      Includes issues related to general domestic m...
# 6      Includes issues related to general domestic m...
# 7      Includes issues related to general domestic m...
# 8      Includes issues related to general domestic m...
# 9      Includes issues related to general domestic m...
# 10     Includes issues related to general domestic m...
# 11     Includes issues related to general domestic m...
# 12     Includes issues related to general domestic m...
# 13     Includes issues related to general domestic m...
# 14     Includes issues related to general domestic m...
# 15     Includes issues related to general domestic m...
# 16     Includes issues related to general domestic m...
# 17     Includes issues related to inflation, cost of...
# 18     Includes issues related to inflation, cost of...
# 19     Includes issues related to the monetary polic...
# 20     Includes issues related to the monetary polic...
# 21     Includes issues related to the monetary polic...
# 22     Includes issues related to the monetary polic...
# 23     Includes issues related to the monetary polic...
# 24     Includes issues related to the monetary polic...
# 25     Includes issues related to the monetary polic...
# 26     Includes issues related to the monetary polic...
# 27     Includes issues related to the monetary polic...
# 28     Includes issues related to the monetary polic...
# 29     Includes issues related to the monetary polic...
# ...                                                 ...
# 4160   Includes issues related to terroritial and de...
# 4161   Includes issues related to terroritial and de...
# 4162   Includes issues related to terroritial and de...
# 4163   Includes issues related to terroritial and de...
# 4164   Includes issues related to terroritial and de...
# 4165   Includes issues related to terroritial and de...
# 4166   Includes issues related to terroritial and de...
# 4167   Includes issues related to terroritial and de...
# 4168   Includes issues related to terroritial and de...
# 4169   Includes issues related to terroritial and de...
# 4170   Includes issues related to terroritial and de...
# 4171   Includes issues related to terroritial and de...
# 4172   Includes issues related to terroritial and de...
# 4173   Includes issues related to terroritial and de...
# 4174   Includes issues related to terroritial and de...
# 4175   Includes issues related to terroritial and de...
# 4176   Includes issues related to terroritial and de...
# 4177   Includes issues related to terroritial and de...
# 4178   Includes issues related to terroritial and de...
# 4179   Includes issues related to terroritial and de...
# 4180   Includes issues related to terroritial and de...
# 4181   Includes issues related to terroritial and de...
# 4182   Includes issues related to terroritial and de...
# 4183   Includes issues related to terroritial and de...
# 4184   Includes issues related to terroritial and de...
# 4185   Includes issues related to terroritial and de...
# 4186   Includes issues related to terroritial and de...
# 4187   Includes issues related to terroritial and de...
# 4188   Includes issues related to terroritial and de...
# 4189   Includes issues related to terroritial and de...
#
# [4190 rows x 9 columns]

# %%
final_df = final_df.astype({"Year": int, "Topic": int, "Sub_Topic": int})
# Setting Executive order Number as Index
# final_df.set_index('Exec Ord#')
final_df.head()
# Out:
#    Exec_Ord  Year President     Party  Topic  Sub_Topic      Topic_Title  \
# 0   12912.0  1994   CLINTON  Democrat      1        100   Macroeconomics
# 1   13497.0  2009     OBAMA  Democrat      1        100   Macroeconomics
# 2   13499.0  2009     OBAMA  Democrat      1        100   Macroeconomics
# 3   13500.0  2009     OBAMA  Democrat      1        100   Macroeconomics
# 4   13501.0  2009     OBAMA  Democrat      1        100   Macroeconomics
#
#   Sub_Topic_Title                                        Description
# 0         General   Includes issues related to general domestic m...
# 1         General   Includes issues related to general domestic m...
# 2         General   Includes issues related to general domestic m...
# 3         General   Includes issues related to general domestic m...
# 4         General   Includes issues related to general domestic m...

# %%
cols1 = ["Exec_Ord", "Year", "President", "Party", "Topic"]
executive_df = final_df[cols1].copy()
executive_df.drop_duplicates(subset=['Exec_Ord'], keep=False)
executive_df.set_index(executive_df.columns[0]).head()
# executive_df.head()
# Out:
#           Year President     Party  Topic
# Exec_Ord
# 12912.0   1994   CLINTON  Democrat      1
# 13497.0   2009     OBAMA  Democrat      1
# 13499.0   2009     OBAMA  Democrat      1
# 13500.0   2009     OBAMA  Democrat      1
# 13501.0   2009     OBAMA  Democrat      1

# %%
cols2 = ["Exec_Ord", "Topic", "Topic_Title", "Sub_Topic", "Sub_Topic_Title", "Description"]
description_df = final_df[cols2].copy()
description_df.drop_duplicates(subset=['Exec_Ord'], keep=False)
description_df.set_index(executive_df.columns[0]).head()
# description_df.head()
# Out:
#           Topic      Topic_Title  Sub_Topic Sub_Topic_Title  \
# Exec_Ord
# 12912.0       1   Macroeconomics        100         General
# 13497.0       1   Macroeconomics        100         General
# 13499.0       1   Macroeconomics        100         General
# 13500.0       1   Macroeconomics        100         General
# 13501.0       1   Macroeconomics        100         General
#
#                                                 Description
# Exec_Ord
# 12912.0    Includes issues related to general domestic m...
# 13497.0    Includes issues related to general domestic m...
# 13499.0    Includes issues related to general domestic m...
# 13500.0    Includes issues related to general domestic m...
# 13501.0    Includes issues related to general domestic m...

# %%
# Create a database connection
connection_string = "root:<insert password>@localhost/ETL_db"
engine = create_engine(f'mysql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['description', 'executive']

# %%
# Loading Data into Database

# %%
executive_df.to_sql(name='executive', con=engine, if_exists='replace', index=True)

# %%
description_df.to_sql('description', engine, if_exists='replace', index=True)
